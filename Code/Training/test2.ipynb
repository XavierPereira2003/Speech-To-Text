# %%
from transformers import pipeline
from datasets import load_dataset, Audio, get_dataset_config_info
import IPython

# %%
model=pipeline('automatic-speech-recognition')
# Out:
# No model was supplied, defaulted to facebook/wav2vec2-base-960h and revision 55bb623 (https://huggingface.co/facebook/wav2vec2-base-960h).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
print(get_dataset_config_info('PolyAI/minds14'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(get_dataset_config_info('PolyAI/minds14'))
#
# File ~/Desktop/Project/NNDL/nndl_env/lib/python3.10/site-packages/datasets/inspect.py:415, in get_dataset_config_info(path, config_name, data_files, download_config, download_mode, revision, token, use_auth_token, **config_kwargs)
#     408     warnings.warn(
#     409         "'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.\n"
#     410         "You can remove this warning by passing 'token=<use_auth_token>' instead.",
#     411         FutureWarning,
#     412     )
#     413     token = use_auth_token
# --> 415 builder = load_dataset_builder(
#     416     path,
#     417     name=config_name,
#     418     data_files=data_files,
#     419     download_config=download_config,
# ...

# %%
# Downloadingg the datasets
Dataset=load_dataset('PolyAI/minds14','en-GB')

# %%
Dataset['train'][0]
# Out:
# {'path': '/home/deon-xavier-pereira/.cache/huggingface/datasets/downloads/extracted/6a4b023a0a2f0658d1de9b352678d6a8e26d7edb5fc9bc1070ce169725d7c252/en-GB~PAY_BILL/60268fc4dc3604f481bcb89c.wav',
#  'audio': {'path': '/home/deon-xavier-pereira/.cache/huggingface/datasets/downloads/extracted/6a4b023a0a2f0658d1de9b352678d6a8e26d7edb5fc9bc1070ce169725d7c252/en-GB~PAY_BILL/60268fc4dc3604f481bcb89c.wav',
#   'array': array([0.        , 0.        , 0.        , ..., 0.01306152, 0.0189209 ,
#          0.04772949]),
#   'sampling_rate': 8000},
#  'transcription': 'I want to pay a bill and I know I want to know how can I use my credit card to do so',
#  'english_transcription': 'I want to pay a bill and I know I want to know how can I use my credit card to do so',
#  'intent_class': 13,
#  'lang_id': 3}

# %%
IPython.display.Audio(Dataset['train'][0]['audio']['array'],rate=8000,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa

# %%
li
